# %% [markdown]
# <a href="https://colab.research.google.com/github/CoolWolfy96/MAT421/blob/main/Module_B_Section_17_1%2C_17_2%2C_17_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Interpolation Problem Statement:** Interpolation is not to be confused with regression.
#
# A interpolation function specifically
#
#
# *   Is a function that passes through **all** data points
# *   Generates values that are between data points
# *   May also generate values before first and after last endpoint
#
# There are many interpolation methods depending on the quality of the function desired i.e. smooth, differentiable, linear, end behaviors.
#
# **Linear Interpolation:** This kind of interpolation uses the slope-intercept formula (y = mx + b) to calculate the function between each pair of points.

# %%
from scipy.interpolate import interp1d
import matplotlib.pyplot as plt

plt.style.use('default')

x = [0, 3, 5, 7]
y = [1, 2, 6, 8]

f = interp1d(x, y)

plt.figure(figsize = (10,8))
plt.plot(x, y, '-ob')
plt.title('Linear Interpolation')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# As is obvious from the name, this kind of interpolation grants a linear function. While this function is continuous, it is not differentiable at every data point (where the function has a sharp turn). A graph of the derivative shows that this is the case. This interpolation should not be used in cases where the function should be differentiable like with physical data.

# %%
x = [0, 3, 3, 5, 5, 9]
y = [1/3, 1/3, 2, 2, 1, 1]

f = interp1d(x, y)

plt.figure(figsize = (10,8))
plt.plot(x, y, '-ob')
plt.title('Derivative of Linear Interpolation')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# **Cubic Spline Interpolation:** This kind of interpolation uses the cubic formula (y = ax^3 + bx^2 + cx + d) to calculate the function between each pair of points.

# %%
from scipy.interpolate import CubicSpline
import numpy as np

x = [0, 3, 5, 7]
y = [1, 2, 6, 8]

f = CubicSpline(x, y, bc_type='natural')
x_new = np.linspace(0, 7, 100)
y_new = f(x_new)

plt.figure(figsize = (10,8))
plt.plot(x_new, y_new, 'b')
plt.plot(x, y, 'ro')
plt.title('Cubic Spline Interpolation')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# This function, its first derivative, and second derivative are all continuous which grants a smooth function. Graphing the first and second derivative can show that this is the case. This interpolation can be used in positional data in order to look at the velocity and acceleration.
